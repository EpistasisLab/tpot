# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score

# %%
X=pd.read_csv("testingData/basicTest/HF_train.txt", sep='\t')
X.head()
# Out:
#        eid  array      pc1      pc2       pc3       pc4       pc5       pc6  \
# 0  2173321      1 -12.1787  2.63696  0.203519  4.625490  11.26250 -1.091930
# 1  4979768      1 -10.9307  3.10202 -0.447919  0.197328  -2.20478  1.093750
# 2  4111782      1 -13.7279  3.71157 -2.816260 -2.594760  -4.55278  0.884419
# 3  2059130      1 -12.4505  4.29629 -0.395055 -0.659687   0.05068 -1.036610
# 4  3484756      1 -11.5569  3.66607 -0.117154  1.045210  -7.18600 -1.953130
#
#         pc7      pc8  ...  indicator_1    adjY_1  indicator_2    adjY_2  \
# 0 -0.798969 -2.10674  ...            1  0.567780            0  0.578435
# 1  0.130705  2.76544  ...            0  0.423497            0  0.417933
# 2  1.212450 -1.92885  ...            0  0.639365            0  0.629162
# 3  0.582252  1.87808  ...            0  0.573545            0  0.545321
# 4  1.957360 -4.92783  ...            0  0.572816            0  0.585846
#
#    indicator_3    adjY_3  indicator_4    adjY_4  indicator_5    adjY_5
# 0            0  0.564814            0  0.581280            1  0.572122
# 1            0  0.434874            0  0.416811            0  0.433987
# 2            1  0.640186            1  0.635849            0  0.644544
# 3            0  0.564933            0  0.556822            1  0.563987
# 4            0  0.567582            0  0.584692            0  0.586635
#
# [5 rows x 34 columns]

# %%
X.columns
# Out:
# Index(['eid', 'array', 'pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'pc7', 'pc8',
#        'pc9', 'pc10', 'rs660240', 'rs17042102', 'rs4135240', 'rs55730499',
#        'rs140570886', 'rs1556516', 'rs600038', 'rs4746140', 'rs17617337',
#        'rs4766578', 'rs56094641', 'adjY', 'indicator_1', 'adjY_1',
#        'indicator_2', 'adjY_2', 'indicator_3', 'adjY_3', 'indicator_4',
#        'adjY_4', 'indicator_5', 'adjY_5'],
#       dtype='object')

# %%
y = X['adjY'] 
X.drop(['adjY', 'eid'], axis=1, inplace=True)
X.head()
# Out:
#    array      pc1      pc2       pc3       pc4       pc5       pc6       pc7  \
# 0      1 -12.1787  2.63696  0.203519  4.625490  11.26250 -1.091930 -0.798969
# 1      1 -10.9307  3.10202 -0.447919  0.197328  -2.20478  1.093750  0.130705
# 2      1 -13.7279  3.71157 -2.816260 -2.594760  -4.55278  0.884419  1.212450
# 3      1 -12.4505  4.29629 -0.395055 -0.659687   0.05068 -1.036610  0.582252
# 4      1 -11.5569  3.66607 -0.117154  1.045210  -7.18600 -1.953130  1.957360
#
#        pc8      pc9  ...  indicator_1    adjY_1  indicator_2    adjY_2  \
# 0 -2.10674  3.60093  ...            1  0.567780            0  0.578435
# 1  2.76544  3.38420  ...            0  0.423497            0  0.417933
# 2 -1.92885 -1.49800  ...            0  0.639365            0  0.629162
# 3  1.87808 -0.48407  ...            0  0.573545            0  0.545321
# 4 -4.92783  5.66661  ...            0  0.572816            0  0.585846
#
#    indicator_3    adjY_3  indicator_4    adjY_4  indicator_5    adjY_5
# 0            0  0.564814            0  0.581280            1  0.572122
# 1            0  0.434874            0  0.416811            0  0.433987
# 2            1  0.640186            1  0.635849            0  0.644544
# 3            0  0.564933            0  0.556822            1  0.563987
# 4            0  0.567582            0  0.584692            0  0.586635
#
# [5 rows x 32 columns]

# %%
X['rs1556516'].head()
# Out:
# 0    1.0
# 1    0.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: rs1556516, dtype: float64

# %%
# test import scorer
from tpot.builtins import resAdjPredefinedSplits
from tpot.builtins import resAdjMseScorer
C_list = ['array',
         'pc1', 
         'pc2', 
         'pc3', 
         'pc4', 
         'pc5', 
         'pc6', 
         'pc7', 
         'pc8', 
         'pc9', 
         'pc10']

# %%
from tpot.config import resAdj_regressor_config_dict
from tpot import TPOTRegressor

resAdj_regressor_config_dict['tpot.builtins.resAdjTransformer'] ={
    'C': C_list,
    'adj_list': ['testingData/basicTest/adj_list.csv']
    
}
n_gen = 5
n_pop = 10


tpot = TPOTRegressor(generations=n_gen, population_size=n_pop, 
                        verbosity=3, cv=resAdjPredefinedSplits(n_splits=5),
                      config_dict=resAdj_regressor_config_dict,
                      template="resAdjTransformer-Transformer-Regressor",
                      scoring=resAdjMseScorer,random_state=42)
tpot.fit(X, y)
# Out:
# 32 operators have been imported by TPOT.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=60.0, style=ProgressStyle(des…
# Skipped pipeline #10 due to time out. Continuing to the next pipeline.
# Skipped pipeline #21 due to time out. Continuing to the next pipeline.
# Generation 1 - Current Pareto front scores:
# -3	-0.20884338823785087	resAdjLinearSVR(resAdjRobustScaler(resAdjTransformer(input_matrix, resAdjTransformer__C=pc2, resAdjTransformer__adj_list=testingData/basicTest/adj_list.csv)), resAdjLinearSVR__C=0.01, resAdjLinearSVR__dual=True, resAdjLinearSVR__epsilon=0.001, resAdjLinearSVR__loss=squared_epsilon_insensitive, resAdjLinearSVR__tol=0.001)
#
# Generation 2 - Current Pareto front scores:
# -3	-0.20884338823785087	resAdjLinearSVR(resAdjRobustScaler(resAdjTransformer(input_matrix, resAdjTransformer__C=pc2, resAdjTransformer__adj_list=testingData/basicTest/adj_list.csv)), resAdjLinearSVR__C=0.01, resAdjLinearSVR__dual=True, resAdjLinearSVR__epsilon=0.001, resAdjLinearSVR__loss=squared_epsilon_insensitive, resAdjLinearSVR__tol=0.001)
#
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Generation 3 - Current Pareto front scores:
# -3	-0.20882657919483041	resAdjLinearSVR(resAdjRobustScaler(resAdjTransformer(input_matrix, resAdjTransformer__C=pc2, resAdjTransformer__adj_list=testingData/basicTest/adj_list.csv)), resAdjLinearSVR__C=0.01, resAdjLinearSVR__dual=True, resAdjLinearSVR__epsilon=0.01, resAdjLinearSVR__loss=squared_epsilon_insensitive, resAdjLinearSVR__tol=0.001)
#
# Generation 4 - Current Pareto front scores:
# -3	-0.20882657919483041	resAdjLinearSVR(resAdjRobustScaler(resAdjTransformer(input_matrix, resAdjTransformer__C=pc2, resAdjTransformer__adj_list=testingData/basicTest/adj_list.csv)), resAdjLinearSVR__C=0.01, resAdjLinearSVR__dual=True, resAdjLinearSVR__epsilon=0.01, resAdjLinearSVR__loss=squared_epsilon_insensitive, resAdjLinearSVR__tol=0.001)
#
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l2' and loss='epsilon_insensitive' are not supported when dual=False, Parameters: penalty='l2', loss='epsilon_insensitive', dual=False.
# Generation 5 - Current Pareto front scores:
# -3	-0.20877427793913877	resAdjLinearSVR(resAdjRobustScaler(resAdjTransformer(input_matrix, resAdjTransformer__C=pc2, resAdjTransformer__adj_list=testingData/basicTest/adj_list.csv)), resAdjLinearSVR__C=0.01, resAdjLinearSVR__dual=False, resAdjLinearSVR__epsilon=0.1, resAdjLinearSVR__loss=squared_epsilon_insensitive, resAdjLinearSVR__tol=0.001)
# TPOTRegressor(config_dict={'tpot.builtins.identity': {},
#                            'tpot.builtins.resAdjAdaBoostRegressor': {'learning_rate': [0.001,
#                                                                                        0.01,
#                                                                                        0.1,
#                                                                                        0.5,
#                                                                                        1.0],
#                                                                      'loss': ['linear',
#                                                                               'square',
#                                                                               'exponential'],
#                                                                      'n_estimators': [100]},
#                            'tpot.builtins.resAdjBinarizer': {'threshold': array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])},
#                            'tp...
#               disable_update_check=False, early_stop=None, generations=5,
#               max_eval_time_mins=5, max_time_mins=None, memory=None,
#               mutation_rate=0.9, n_jobs=1, offspring_size=None,
#               periodic_checkpoint_folder=None, population_size=10,
#               random_state=42,
#               scoring=<function resAdjMseScorer at 0x1a21e44ea0>, subsample=1.0,
#               template='resAdjTransformer-Transformer-Regressor',
#               use_dask=False, verbosity=3, warm_start=False)
